# %%
import os
import sys

sys.path.append('../..')

import numpy as np
import pandas as pd
import matplotlib as plt
import sklearn
# %matplotlib inline
# %pylab inline
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

df = pd.read_hdf("../../data_extract/features_dataset_2b.h5")
from pandas.tools.plotting import scatter_matrix

import pylab as pl
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# #### Plotting Chroma1 for each person gives a kind of exponential graph (similar for each chroma feature)

# %%
hist1 = df.hist(column="chroma1", by="id", bins=30, figsize=(20,20))

# %% [markdown]
# #### Plotting log(Chroma1) for each person gives a gaussian distribution (similar for others)

# %%
df["lc1"] = np.log(df["chroma1"])
hist1 = df.hist(column="lc1", by="id", bins=30, figsize=(20,20))
pl.suptitle("Plot of log(chroma1) for Persons",fontsize=30)

# %%
hist1 = df.hist(column="mfcc1", by="id", bins=30, figsize=(20,20))
