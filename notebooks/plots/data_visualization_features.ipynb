# %%
import os
import sys

sys.path.append('../..')

import numpy as np
import pandas as pd
import matplotlib as plt
import sklearn
# %matplotlib inline
# %pylab inline
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

df = pd.read_hdf("../../data_extract/features_dataset_2b.h5")
from pandas.tools.plotting import scatter_matrix

import pylab as pl
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /home/anshul/anaconda2/envs/voice/lib/python2.7/site-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['plt']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %% [markdown]
# #### Plotting Chroma1 for each person gives a kind of exponential graph (similar for each chroma feature)

# %%
# fig, axes = plt.subplots(2,2)
hist1 = df[df['id']<16].hist(column="chroma1", by="pname", sharex=False, bins=50, figsize=(10,10))

# %% [markdown]
# #### Plotting log(Chroma1) for each person gives a gaussian distribution (similar for others)

# %%
df["lc1"] = np.log(df["chroma2"])
hist1 = df[df['id']<16].hist(column="lc1", by="pname", bins=50, figsize=(10,10))
pl.suptitle("Plot of log(chroma1) for first 9 persons",fontsize=12);

# %%
hist1 = df.hist(column="mfcc1", by="id", bins=30, figsize=(20,20))
