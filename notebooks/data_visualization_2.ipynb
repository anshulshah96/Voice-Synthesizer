# %%
import os
import sys

sys.path.append('..')

import numpy as np
import pandas as pd
import matplotlib as plt
import sklearn
# %matplotlib inline
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

df = pd.read_hdf("../data_extract/features_dataset_2b.h5")

# %% [markdown]
# #### Plotting Chroma1 for each person gives a kind of exponential graph (similar for each chroma feature)

# %%
hist1 = df.hist(column="chroma1", by="pid", bins=30, figsize=(20,20))

# %% [markdown]
# #### Plotting log(Chroma1) for each person gives a gaussian distribution (similar for others)

# %%
df["lc1"] = np.log(df["chroma1"])
hist1 = df.hist(column="lc1", by="pid", bins=30, figsize=(20,20))

# %%
hist1 = df.hist(column="mfcc1", by="pid", bins=30, figsize=(20,20))
